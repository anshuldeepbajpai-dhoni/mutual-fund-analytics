# %% [markdown]
# ### Project Title

# %%
print("Mutual Fund Analytics Capstone Project")
print("Day 1 - Project Setup and Data Ingestion")
# Out:
# Mutual Fund Analytics Capstone Project
# Day 1 - Project Setup and Data Ingestion

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import requests
from pathlib import Path

# %% [markdown]
# ### Define Data Path

# %%
DATA_PATH = "../data/raw"

print("Data_Path:", DATA_PATH)
# Out:
# Data_Path: ../data/raw

# %% [markdown]
# ### Load All 10 Datasets

# %%
fund_master = pd.read_csv(f"{DATA_PATH}/01_fund_master.csv")

nav_history = pd.read_csv(f"{DATA_PATH}/02_nav_history.csv")

aum_by_fund_house = pd.read_csv(
    f"{DATA_PATH}/03_aum_by_fund_house.csv"
)

monthly_sip_inflows = pd.read_csv(
    f"{DATA_PATH}/04_monthly_sip_inflows.csv"
)

category_inflows = pd.read_csv(
    f"{DATA_PATH}/05_category_inflows.csv"
)

industry_folio_count = pd.read_csv(
    f"{DATA_PATH}/06_industry_folio_count.csv"
)

scheme_performance = pd.read_csv(
    f"{DATA_PATH}/07_scheme_performance.csv"
)

investor_transactions = pd.read_csv(
    f"{DATA_PATH}/08_investor_transactions.csv"
)

portfolio_holdings = pd.read_csv(
    f"{DATA_PATH}/09_portfolio_holdings.csv"
)

benchmark_indices = pd.read_csv(
    f"{DATA_PATH}/10_benchmark_indices.csv"
)

print("All datasets loaded successfully.")
# Out:
# All datasets loaded successfully.

# %% [markdown]
# ### Store in Dictionary

# %%
datasets = {
    "fund_master": fund_master,
    "nav_history": nav_history,
    "aum_by_fund_house": aum_by_fund_house,
    "monthly_sip_inflows": monthly_sip_inflows,
    "category_inflows": category_inflows,
    "industry_folio_count": industry_folio_count,
    "scheme_performance": scheme_performance,
    "investor_transactions": investor_transactions,
    "portfolio_holdings": portfolio_holdings,
    "benchmark_indices": benchmark_indices
}

# %% [markdown]
# ### Display Shape

# %%
for name, df in datasets.items():
    print("="*60)
    print(name.upper())
    print("="*60)

    print("Shape:", df.shape)
    print()
# Out:
# ...
# FUND_MASTER
# ...
# Shape: (40, 15)
#
# ...
# NAV_HISTORY
# ...
# Shape: (46000, 3)
#
# ...
# AUM_BY_FUND_HOUSE
# ...
# Shape: (90, 5)
#
# ...
# MONTHLY_SIP_INFLOWS
# ...
# Shape: (48, 6)
#
# ...
# CATEGORY_INFLOWS
# ...
# Shape: (144, 3)
#
# ...
# INDUSTRY_FOLIO_COUNT
# ...
# Shape: (21, 6)
#
# ...
# SCHEME_PERFORMANCE
# ...
# Shape: (40, 19)
#
# ...
# INVESTOR_TRANSACTIONS
# ...
# Shape: (32778, 13)
#
# ...
# PORTFOLIO_HOLDINGS
# ...
# Shape: (322, 8)
#
# ...
# BENCHMARK_INDICES
# ...
# Shape: (8050, 3)

# %% [markdown]
# ###  Display Data Types

# %%
for name, df in datasets.items():
    print("="*60)
    print(name.upper())
    print("="*60)

    print(df.dtypes)
    print()
# Out:
# ...
# FUND_MASTER
# ...
# amfi_code               int64
# fund_house             object
# scheme_name            object
# category               object
# sub_category           object
# plan                   object
# launch_date            object
# benchmark              object
# expense_ratio_pct     float64
# exit_load_pct         float64
# min_sip_amount          int64
# min_lumpsum_amount      int64
# fund_manager           object
# risk_category          object
# sebi_category_code     object
# dtype: object
#
# ...
# NAV_HISTORY
# ...
# amfi_code      int64
# date          object
# nav          float64
# dtype: object
#
# ...
# AUM_BY_FUND_HOUSE
# ...
# date               object
# fund_house         object
# aum_lakh_crore    float64
# aum_crore           int64
# num_schemes         int64
# dtype: object
#
# ...
# MONTHLY_SIP_INFLOWS
# ...
# month                         object
# sip_inflow_crore               int64
# active_sip_accounts_crore    float64
# new_sip_accounts_lakh        float64
# ...

# %% [markdown]
# ### Display First 5 Records

# %%
for name, df in datasets.items():

    print("="*60)
    print(name.upper())
    print("="*60)

    display(df.head())
# Out:
# ...
# FUND_MASTER
# ...
#    amfi_code       fund_house                                   scheme_name  \
# 0     119551  SBI Mutual Fund     SBI Bluechip Fund - Regular Plan - Growth
# 1     119552  SBI Mutual Fund      SBI Bluechip Fund - Direct Plan - Growth
# 2     119598  SBI Mutual Fund    SBI Small Cap Fund - Regular Plan - Growth
# 3     119599  SBI Mutual Fund     SBI Small Cap Fund - Direct Plan - Growth
# 4     119120  SBI Mutual Fund  SBI Magnum Gilt Fund - Regular Plan - Growth
#
#   category sub_category     plan launch_date                  benchmark  \
# 0   Equity    Large Cap  Regular  2006-02-14              NIFTY 100 TRI
# 1   Equity    Large Cap   Direct  2013-01-01              NIFTY 100 TRI
# 2   Equity    Small Cap  Regular  2009-09-09       BSE 250 SmallCap TRI
# 3   Equity    Small Cap   Direct  2013-01-01       BSE 250 SmallCap TRI
# 4     Debt         Gilt  Regular  2000-12-30  CRISIL Dynamic Gilt Index
#
# ...

# %% [markdown]
# ### Missing Values Check

# %%
for name, df in datasets.items():

    print("="*60)
    print(name.upper())
    print("="*60)

    print(df.isnull().sum())
    print()
# Out:
# ...
# FUND_MASTER
# ...
# amfi_code             0
# fund_house            0
# scheme_name           0
# category              0
# sub_category          0
# plan                  0
# launch_date           0
# benchmark             0
# expense_ratio_pct     0
# exit_load_pct         0
# min_sip_amount        0
# min_lumpsum_amount    0
# fund_manager          0
# risk_category         0
# sebi_category_code    0
# dtype: int64
#
# ...
# NAV_HISTORY
# ...
# amfi_code    0
# date         0
# nav          0
# dtype: int64
#
# ...
# AUM_BY_FUND_HOUSE
# ...
# date              0
# fund_house        0
# aum_lakh_crore    0
# aum_crore         0
# num_schemes       0
# dtype: int64
#
# ...
# MONTHLY_SIP_INFLOWS
# ...
# month                         0
# sip_inflow_crore              0
# active_sip_accounts_crore     0
# new_sip_accounts_lakh         0
# sip_aum_lakh_crore            0
# yoy_growth_pct               12
# dtype: int64
#
# ...
# CATEGORY_INFLOWS
# ...
# month               0
# category            0
# net_inflow_crore    0
# dtype: int64
# ...

# %% [markdown]
# ### Duplicate Records Check

# %%
for name, df in datasets.items():

    print("="*60)
    print(name.upper())
    print("="*60)

    print("Duplicates:", df.duplicated().sum())
# Out:
# ...
# FUND_MASTER
# ...
# Duplicates: 0
# ...
# NAV_HISTORY
# ...
# Duplicates: 0
# ...
# AUM_BY_FUND_HOUSE
# ...
# Duplicates: 0
# ...
# MONTHLY_SIP_INFLOWS
# ...
# Duplicates: 0
# ...
# CATEGORY_INFLOWS
# ...
# Duplicates: 0
# ...
# INDUSTRY_FOLIO_COUNT
# ...
# Duplicates: 0
# ...
# SCHEME_PERFORMANCE
# ...
# Duplicates: 0
# ...
# INVESTOR_TRANSACTIONS
# ...
# Duplicates: 0
# ...
# PORTFOLIO_HOLDINGS
# ...
# Duplicates: 0
# ...
# BENCHMARK_INDICES
# ...
# Duplicates: 0

# %% [markdown]
# ### Dataset Summary

# %%
for name, df in datasets.items():

    print("="*60)
    print(name.upper())
    print("="*60)

    display(df.describe(include="all"))
# Out:
# ...
# FUND_MASTER
# ...
#             amfi_code       fund_house  \
# count       40.000000               40
# unique            NaN               10
# top               NaN  SBI Mutual Fund
# freq              NaN                5
# mean    120247.000000              NaN
# std      14534.998667              NaN
# min     100016.000000              NaN
# 25%     118632.750000              NaN
# 50%     119551.500000              NaN
# 75%     120842.250000              NaN
# max     149324.000000              NaN
#
#                                       scheme_name category sub_category  \
# count                                          40       40           40
# unique                                         40        2           12
# top     SBI Bluechip Fund - Regular Plan - Growth   Equity    Large Cap
# freq                                            1       34           14
# mean                                          NaN      NaN          NaN
# ...

# %% [markdown]
# ### Fetch Live NAV Data

# %%
import requests

scheme_code = 119551

url = f"https://api.mfapi.in/mf/{scheme_code}"

response = requests.get(url)

if response.status_code == 200:
    data = response.json()

    print("Scheme Name:")
    print(data["meta"]["scheme_name"])

    print("\nLatest NAV:")
    print(data["data"][0])

else:
    print("API request failed")
# Out:
# Scheme Name:
# Aditya Birla Sun Life Banking & PSU Debt Fund  - DIRECT - IDCW
#
# Latest NAV:
# {'date': '23-06-2026', 'nav': '106.04100'}

# %% [markdown]
# ### Day 1 Completion Summary

# %%
print("Day 1 Completed Successfully")

print("""
Tasks Completed:

✔ Project Structure Created
✔ 10 CSV Files Loaded
✔ Shape Checked
✔ Data Types Checked
✔ Head Records Viewed
✔ Missing Values Checked
✔ Duplicates Checked
✔ Live NAV API Tested
✔ Ready For Day 2 Data Cleaning
""")
# Out:
# Day 1 Completed Successfully
#
# Tasks Completed:
#
# ✔ Project Structure Created
# ✔ 10 CSV Files Loaded
# ✔ Shape Checked
# ✔ Data Types Checked
# ✔ Head Records Viewed
# ✔ Missing Values Checked
# ✔ Duplicates Checked
# ✔ Live NAV API Tested
# ✔ Ready For Day 2 Data Cleaning
